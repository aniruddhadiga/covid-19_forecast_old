# %%
import numpy as np
import pandas as pd
from collections import defaultdict

# %%
fct_dates = ['2020-04-05', '2020-04-12', '2020-04-19', '2020-04-26', '2020-05-03',
       '2020-05-10', '2020-05-17', '2020-05-24', '2020-05-31',
       '2020-06-07', '2020-06-14', '2020-06-21', '2020-06-28',
       '2020-07-05', '2020-07-12', '2020-07-19', '2020-07-26',
       '2020-08-02', '2020-08-09', '2020-08-16', '2020-08-23',
       '2020-08-30', '2020-09-06', '2020-09-13', '2020-09-20',
       '2020-09-27', '2020-10-04', '2020-10-11', '2020-10-18']

# %%
gt_dates = ["2020-03-01_2020-03-07", "2020-03-08_2020-03-14", "2020-03-15_2020-03-21", 
            "2020-03-22_2020-03-28", "2020-03-29_2020-04-04", "2020-04-05_2020-04-11",
            "2020-04-12_2020-04-18", "2020-04-19_2020-04-25", "2020-04-26_2020-05-02",
            "2020-05-03_2020-05-09", "2020-05-10_2020-05-16", "2020-05-17_2020-05-23",
            "2020-05-24_2020-05-30", "2020-05-31_2020-06-06", "2020-06-07_2020-06-13",
            "2020-06-14_2020-06-20", "2020-06-21_2020-06-27", "2020-06-28_2020-07-04",
            "2020-07-05_2020-07-11", "2020-07-12_2020-07-18", "2020-07-19_2020-07-25",
            "2020-07-26_2020-08-01", "2020-08-02_2020-08-08", "2020-08-09_2020-08-15",
            "2020-08-16_2020-08-22", "2020-08-23_2020-08-29", "2020-08-30_2020-09-05",
            "2020-09-06_2020-09-12", "2020-09-13_2020-09-19", "2020-09-20_2020-09-26", 
            "2020-09-27_2020-10-03", "2020-10-04_2020-10-10", "2020-10-11_2020-10-17",
            "2020-10-18_2020-10-24", "2020-10-25_2020-10-31", "2020-11-01_2020-11-07",
            "2020-11-08_2020-11-14", "2020-11-15_2020-11-21", "2020-11-22_2020-11-28"]

# %%
import json

for i in range(5,len(gt_dates)-4):
    data = {}
    data['gt_dates'] = gt_dates[:i+1]
    data['skip_date'] = '2020-03-01_2020-03-07'  
    data['train_date'] = gt_dates[i]
    data['fct_date'] = gt_dates[i+1:i+5]
    with open('../cfg/cfg-{}'.format(gt_dates[i].split('_')[0]), 'w') as outfile:
        json.dump(data, outfile)

# %%
import os
from shutil import copy2
for i in range(12,len(fct_dates)):
    path1 = '/project/biocomplexity/lw8bn/google-mobility/DNN/{}'.format(fct_dates[i])
#     path2 = '/project/biocomplexity/lw8bn/google-mobility/DNN/{}/prediction'.format(fct_dates[i])
#     path3 = '/project/biocomplexity/lw8bn/google-mobility/DNN/{}/model'.format(fct_dates[i])
#     os.makedirs(path1)
#     os.makedirs(path2)
#     os.makedirs(path3)
#     copy2('../cfg/cfg-{}'.format(fct_dates[i]), path1+'/cfg')
#     copy2('../output-lstm-ensemble/run.sh', path1)
#     copy2('../output-lstm-ensemble/run.slurm', path1)
    copy2(path1+'/prediction/prediction-fmt.csv', '/project/biocomplexity/lw8bn/GitRepo/covid-19_forecast/output/LSTM_ensemble/LSTM_ensemble-{}.csv'.format(fct_dates[i]))

# %% [raw]
# cd 2020-04-05/prediction
# ../run.sh
# cd ../../
# cd 2020-04-12/prediction
# ../run.sh
# cd ../../
# cd 2020-04-19/prediction
# ../run.sh
# cd ../../
# cd 2020-04-26/prediction
# ../run.sh
# cd ../../
# cd 2020-05-03/prediction
# ../run.sh
# cd ../../
# cd 2020-05-10/prediction
# ../run.sh
# cd ../../
#
# cd 2020-05-17/prediction
# ../run.sh
# cd ../../
# cd 2020-05-24/prediction
# ../run.sh
# cd ../../
# cd 2020-05-31/prediction
# ../run.sh
# cd ../../
# cd 2020-06-07/prediction
# ../run.sh
# cd ../../
# cd 2020-06-14/prediction
# ../run.sh
# cd ../../
# cd 2020-06-21/prediction
# ../run.sh
# cd ../../
#
# cd 2020-06-28/prediction
# ../run.sh
# cd ../../
# cd 2020-07-05/prediction
# ../run.sh
# cd ../../
# cd 2020-07-12/prediction
# ../run.sh
# cd ../../
# cd 2020-07-19/prediction
# ../run.sh
# cd ../../
# cd 2020-07-26/prediction
# ../run.sh
# cd ../../
# cd 2020-08-02/prediction
# ../run.sh
# cd ../../
#
# cd 2020-08-09/prediction
# ../run.sh
# cd ../../
# cd 2020-08-16/prediction
# ../run.sh
# cd ../../
# cd 2020-08-23/prediction
# ../run.sh
# cd ../../
# cd 2020-08-30/prediction
# ../run.sh
# cd ../../
# cd 2020-09-06/prediction
# ../run.sh
# cd ../../
# cd 2020-09-13/prediction
# ../run.sh
# cd ../../
#
# cd 2020-09-20/prediction
# ../run.sh
# cd ../../
# cd 2020-09-27/prediction
# ../run.sh
# cd ../../
# cd 2020-10-04/prediction
# ../run.sh
# cd ../../
# cd 2020-10-11/prediction
# ../run.sh
# cd ../../
# cd 2020-10-18/prediction
# ../run.sh
# cd ../../
